# %%
from import_dados import *

# %%
pessoas = read_pessoas()
sinistros = read_sinistros()
veiculos = read_veiculos()

# %%
colunas_sinistro = ['id_sinistro',
                    'tipo_registro',
                    'data_sinistro',
                    'ano_sinistro',
                    'mes_sinistro',
                    'dia_sinistro',
                    'hora_sinistro',
                    'ano_mes_sinistro',
                    'dia_da_semana',
                    'turno',
                    'logradouro',
                    'numero_logradouro',
                    'tipo_via',
                    'tipo_local',
                    'latitude',
                    'longitude',
                    'cod_ibge',
                    'municipio',
                    'regiao_administrativa',
                    'administracao',
                    'conservacao',
                    'circunscricao']

colunas_pessoa =   ['id_sinistro',
                    'id_pessoa',
                    'id_veiculo',
                    'tipo_veiculo_vitima',
                    'tipo_de_vitima',
                    'modo_transporte_vitima',
                    'sexo',
                    'idade',
                    'gravidade_lesao',
                    'faixa_etaria_demografica',
                    'faixa_etaria_legal',
                    'profissao',
                    'grau_de_instrucao',
                    'nacionalidade',
                    'data_obito',
                    'ano_obito',
                    'mes_obito',
                    'dia_obito',
                    'ano_mes_obito',
                    'local_obito',
                    'local_via',
                    'tempo_sinistro_obito']

colunas_veiculo =  ['id_sinistro',
                    'id_veiculo',
                    'marca_modelo',
                    'ano_fab',
                    'ano_modelo',
                    'cor_veiculo',
                    'tipo_veiculo']

# %%
sinistros.filter(pl.col('id_sinistro') == 2456253)
# Out:
# shape: (1, 50)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id_sinist ┆ tipo_regi ┆ data_sini ┆ ano_sinis ┆ … ┆ tp_sinist ┆ tp_sinist ┆ tp_sinist ┆ tp_sinis │
# │ ro        ┆ stro      ┆ stro      ┆ tro       ┆   ┆ ro_engave ┆ ro_tombam ┆ ro_outros ┆ tro_nao_ │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ tamento   ┆ ento      ┆ ---       ┆ disponiv │
# │ i64       ┆ str       ┆ str       ┆ i64       ┆   ┆ ---       ┆ ---       ┆ str       ┆ el       │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ str       ┆           ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2456253   ┆ SINISTRO  ┆ 05/07/202 ┆ 2024      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆ FATAL     ┆ 4         ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
pessoas.filter(pl.col('id_sinistro') == 2456253)
# Out:
# shape: (10, 31)
# ┌───────────┬───────────┬───────────┬──────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ id_sinist ┆ id_pessoa ┆ id_veicul ┆ cod_ibge ┆ … ┆ ano_mes_o ┆ local_obi ┆ local_via ┆ tempo_sin │
# │ ro        ┆ ---       ┆ o         ┆ ---      ┆   ┆ bito      ┆ to        ┆ ---       ┆ istro_obi │
# │ ---       ┆ i64       ┆ ---       ┆ i64      ┆   ┆ ---       ┆ ---       ┆ str       ┆ to        │
# │ i64       ┆           ┆ i64       ┆          ┆   ┆ str       ┆ str       ┆           ┆ ---       │
# │           ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆ i64       │
# ╞═══════════╪═══════════╪═══════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2456253   ┆ 532       ┆ null      ┆ 3529302  ┆ … ┆ null      ┆ null      ┆ PUBLICO   ┆ null      │
# │ 2456253   ┆ 138       ┆ null      ┆ 3529302  ┆ … ┆ null      ┆ null      ┆ PUBLICO   ┆ null      │
# │ 2456253   ┆ 377       ┆ null      ┆ 3529302  ┆ … ┆ null      ┆ null      ┆ PUBLICO   ┆ null      │
# │ 2456253   ┆ 95        ┆ 2280594   ┆ 3529302  ┆ … ┆ 2024/07   ┆ ESTABELEC ┆ PUBLICO   ┆ 0         │
# │           ┆           ┆           ┆          ┆   ┆           ┆ IMENTO DE ┆           ┆           │
# │           ┆           ┆           ┆          ┆   ┆           ┆ SAUDE     ┆           ┆           │
# │ 2456253   ┆ 462       ┆ null      ┆ 3529302  ┆ … ┆ null      ┆ null      ┆ PUBLICO   ┆ null      │
# │ 2456253   ┆ 660       ┆ null      ┆ 3529302  ┆ … ┆ null      ┆ null      ┆ PUBLICO   ┆ null      │
# │ 2456253   ┆ 835       ┆ null      ┆ 3529302  ┆ … ┆ null      ┆ null      ┆ PUBLICO   ┆ null      │
# │ 2456253   ┆ 1185      ┆ null      ┆ 3529302  ┆ … ┆ null      ┆ null      ┆ PUBLICO   ┆ null      │
# │ 2456253   ┆ 185       ┆ null      ┆ 3529302  ┆ … ┆ null      ┆ null      ┆ PUBLICO   ┆ null      │
# │ 2456253   ┆ 132       ┆ null      ┆ 3529302  ┆ … ┆ null      ┆ null      ┆ PUBLICO   ┆ null      │
# └───────────┴───────────┴───────────┴──────────┴───┴───────────┴───────────┴───────────┴───────────┘
